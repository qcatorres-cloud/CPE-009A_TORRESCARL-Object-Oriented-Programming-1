# %% [markdown]
# <a href="https://colab.research.google.com/github/qcatorres-cloud/CPE-009A_TORRESCARL-Object-Oriented-Programming-1/blob/main/CONTROL_STRUCTURES_TORRES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **CONTROL STRUCTURES**

# %% [markdown]
# IF Statement

# %%
a = 12
b = 100
if b>a:
  print("b is greater than a")
# Out:
# b is greater than a

# %% [markdown]
# ELIF Statement

# %%
a = 12
b = 12
if b > a:
  print("b is greater than a")

elif a == b:
  print("a and b are equal")
# Out:
# a and b are equal

# %%
a = 200
b = 33
if b > a:
  print("b is greater than a")

elif a == b:
  print("a and b are equal")

else:
  print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# Short Hand IF Statement

# %%
if a > b: print("a is greater than b")
# Out:
# a is greater than b

# %%
a = 2
b = 330
print("A") if a > b else print("B")
# Out:
# B

# %% [markdown]
# AND-BOTH Conditions are True

# %%
a = 200
b = 33
c = 500
if a > b and c > a:
  print("Both conditions are True")
# Out:
# Both conditions are True

# %% [markdown]
# OR-AT Least one of the conditions is true

# %%
a = 200
b = 33
c = 500
if a > b or a > c:
  print("At least one of the conditions is True")
# Out:
# At least one of the conditions is True

# %% [markdown]
# NESTED IF Statement

# %%
x = 41

if x > 10:
  print("Above ten,")
  if x > 20:
    print("and also above 20!")
  else:
    print("but not above 20.")
# Out:
# Above ten,
# and also above 20!

# %%
x = 41

if x > 10:
  print("Above ten,")
  if x > 20:
    print("and also above 20!")
  else:
    print("but not above 20.")

# %%
x = 41

if x > 10:
  print("Above ten,")
  if x > 20:
    print("and also above 20!")
    if x > 30:
      print ("and also above 30")
      if x > 40:
        print ("and also above 40")
        if x < 50:
          print ("and also below 50")
        else :
            print("above 40")
      else:
        print("below 40")
    else:
      print("below 30")
  else:
    print("below 20.")
else:
  print("below 10")
# Out:
# Above ten,
# and also above 20!
# and also above 30
# and also above 40
# and also below 50

# %% [markdown]
# Example 1 Supplementary Activity

# %%
print("Enter your Age")
x = int(input())

if x > 18:
  print("You are qualified to vote")
  if x > 18:
    print("You are above 18 years old")
  else:
    print ("You are below 18 years old")
else:
  print("You are not qualified to vote")
# Out:
# Enter your Age
# 19
# You are qualified to vote
# You are above 18 years old

# %% [markdown]
# Example 2 Supplementary Activity

# %%
print("Enter the Number")
x = int(input())

if x < 0:
  print("Negative Number")
elif x > 0:
  print("Positive Number")
elif x == 0:
  print("Zero")
# Out:
# Enter the Number
# 0
# Zero

# %% [markdown]
# Example 3 Supplementary Activity

# %%
print("Enter your Grade") #5 points
x = int(input())

if x >= 75:
  print("Passed")
elif x == 74:
  print("Remedial")
elif x < 74:
  print("Failed")
  if x < 0:
    print("Invalid Input")
else:
  print("Valid Input")
# Out:
# Enter your Grade
# -3
# Failed
# Invalid Input
