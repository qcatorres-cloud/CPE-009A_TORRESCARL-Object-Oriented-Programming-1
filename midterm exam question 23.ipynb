# %% [markdown]
# <a href="https://colab.research.google.com/github/qcatorres-cloud/CPE-009A_TORRESCARL-Object-Oriented-Programming-1/blob/main/midterm%20exam%20question%2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #QUESTION 23
# Instruction: Insert the link of your program(Colab/Github) here.
#
# Write a program that uses nested loops to print this pattern:
#
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
for i in range(1,6,1):
  print ("*"*i)
for i in range(4,0,-1):
  print ("*"*i)
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *
