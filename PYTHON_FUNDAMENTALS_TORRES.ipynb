# %% [markdown]
# <a href="https://colab.research.google.com/github/qcatorres-cloud/CPE-009A_TORRESCARL-Object-Oriented-Programming-1/blob/main/PYTHON_FUNDAMENTALS_TORRES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Python Indentation**

# %%
if 5>2:
  print("Five is greater than two!")
# Out:
# Five is greater than two!

# %% [markdown]
# **Python Comments**

# %%
#This is a comment
print("Hello, World")
# Out:
# Hello, World

# %% [markdown]
# **Python Variable**

# %%
#Example
x = 1
a, b = 0,-1
a, b, c=0,-1,2
print(x + a, b, c)
print(x, a, b, c)
print(x + a, b * a, c)
# Out:
# 1 -1 2
# 1 0 -1 2
# 1 0 2

# %%
#Others
b = "Sally" #This is a type of string
print(b)
# Out:
# Sally

# %% [markdown]
# **Casting**

# %%
b = "sally" #This is a type of string
b = int(4)
print(b)

b = float(4)
print(b)
# Out:
# 4
# 4.0

# %% [markdown]
# **Type() Function**

# %%
x = 5
y = "John"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# **"Double Quotes" or "Single Quotes"**

# %%
y = "John"
print(y)
y = 'John'
print(y)
# Out:
# John
# John

# %% [markdown]
# **Case Sensitive**

# %%
a = 4
A = "Sally"
#A will not overwrite a
print(a)
print(A)
# Out:
# 4
# Sally

# %% [markdown]
# **Multiple Variables**

# %%
x, y, z = "one", "two", "three"
print(x)
print(y)
print(z)
# Out:
# one
# two
# three

# %% [markdown]
# **One Value to Multiple Variables**

# %%
x = y = z = "four"
print(x)
print(y)
print(z)
# Out:
# four
# four
# four

# %% [markdown]
# **Output Variables**

# %%
x = "enjoying"
print ("Python programming is " + x)
# Out:
# Python programming is enjoying

# %%
#Other Way
x = "Python is "
y = "enjoying"
z = x + y
print(z)
# Out:
# Python is enjoying

# %% [markdown]
# **Arithmetic Operations**

# %%
#Addition
x = 5
y = 3
print(x+y)

x = 5
y = 3
sum = x + y
print(sum)
# Out:
# 8
# 8

# %%
#Subtraction
x = 5
y = 3
print(x-y)

x = 5
y = 3
sum = x - y
print(sum)
# Out:
# 2
# 2

# %%
#Multiplication
x = 5
y = 3
print(x*y)

x = 5
y = 3
sum = x * y
print(sum)
# Out:
# 15
# 15

# %%
#Modulo
x = 5
y = 3
print(x%y)

x = 5
y = 3
sum = x % y
print(sum)
# Out:
# 2
# 2

# %%
#Division
x = 5
y = 3
print(x/y)

x = 5
y = 3
sum = x / y
print(sum)
# Out:
# 1.6666666666666667
# 1.6666666666666667

# %%
#Floor Division 1
x = 5
y = 3
print(x//y)

x = 5
y = 3
sum = x // y
print(sum)
# Out:
# 1
# 1

# %%
#Floor Division 2
10 // 3
# Out:
# 3

# %% [markdown]
# **Assignment Operators**

# %%
s = 1
s+=3
print(s)
# Out:
# 4

# %%
s = 1
s-=3
print(s)
# Out:
# -2

# %%
s = 1
s*=3
print(s)
# Out:
# 3

# %%
s = 1
s/=3
print(s)
# Out:
# 0.3333333333333333

# %%
s = 1
s%=3
print(s)
# Out:
# 1

# %%
s = 1
s//=3
print(s)
# Out:
# 0

# %%
s = 1
s**=3
print(s)
# Out:
# 1

# %%
s = 1
s&=3
print(s)
# Out:
# 1

# %%
s = 1
s|=3
print(s)
# Out:
# 3

# %%
s = 1
s^=3
print(s)
# Out:
# 2

# %%
s = 1
s>>=3
print(s)
# Out:
# 0

# %%
s = 1
s<<=3
print(s)
# Out:
# 8

# %% [markdown]
# **Comparison Operators**

# %%
t = 1
u = 2
print(t == u)
# Out:
# False

# %%
t = 1
u = 2
print(t != u)
# Out:
# True

# %%
t = 1
u = 2
print(t > u)
# Out:
# False

# %%
t = 1
u = 2
print(t < u)
# Out:
# True

# %%
t = 1
u = 2
print(t >= u)
# Out:
# False

# %%
t = 1
u = 2
print(t <= u)
# Out:
# True

# %% [markdown]
# **Logical Operators**

# %%
t = 1
u = 2

print(t < 0 and t < 10)
print(u < 5 or u < 10)
print(not(t < 3 and u < 10))
# Out:
# True
# True
# False

# %% [markdown]
# **Identity Operators**

# %%
x = {"apple", "banana"}
y = {"apple", "banana"}
z = x

print(x is z)
print(x is y)
print(x == y)
# Out:
# True
# False
# True

# %% [markdown]
# **Bitwise Operators**

# %%
v = 2
v << 1
v << 2
# Out:
# 8
