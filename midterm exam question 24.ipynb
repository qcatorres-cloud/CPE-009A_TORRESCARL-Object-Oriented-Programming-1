# %% [markdown]
# <a href="https://colab.research.google.com/github/qcatorres-cloud/CPE-009A_TORRESCARL-Object-Oriented-Programming-1/blob/main/midterm%20exam%20question%2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Question 24

# %%
def strbal():
 str = input("Enter a string of parentheses, brackets, and braces: ")
if str == "(" or str == "{" or str == "]":
  print("True")
if str == ")" or str == "}" or str == "]":
  print("False")

check str = '({[]})'
print("True")
check str = '([)]'
print("False")
check str = '((()))'
print("True")
check str = '({)}'
print("False")
strbal()
print(strbal())
# Out:
#   File "/tmp/ipykernel_575/3940562312.py", line 8
#     check str = '({[]})'
#           ^
# SyntaxError: invalid syntax
