# %% [markdown]
# <a href="https://colab.research.google.com/github/qcatorres-cloud/CPE-009A_TORRESCARL-Object-Oriented-Programming-1/blob/main/Hands_on_Activity_2_1_Literals_and_Variables_(TORRES_CPE12S2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# <center>
#
# **Technological Institute of the Philippines**<br>
# Computer Engineering Department<br>
# Quezon city Campus</center>
#
# ---
# <center><h4> Activity No. and Title: Hands-on Activity 2.1 Literals and Variables</h4></center>
#
# ---
# <center>
#
# | Course: CPE 009 | Program: BSCpE |
# |--- | --- |
# | **Course Title**: Object Oriented Programming | **Date Performed: Jan. 15, 2026** |
# | **Section**: CPE12S2  | **Date Submitted: Jan. 15, 2026** |
# | **Student Name**: Carl Andrei D. Torres  | **Instructor's Name: ENGR. Maria Rizette Sayo** |
# </center>

# %% [markdown]
# **Objective/s of the activity:**
#
# 1.  Implement literals and variables in a python program.
# 2.
#
# **Intended Learning Outcome:**
#
# 1.  Write a simple program implementing literals and variables.
# 2.  Use comments and identify keywords from identifiers created by users.
#
# **Discussion:**
#
# Discuss the use of variables, constants and literals in a python program.
#
# **Materials and Equipment:**
#
# 1.   List item
# 2.   List item
#
# **Procedure:**
#
# 1.  A teacher wants to calculate the final grade in a CpE course and want to write it in a python program. The following are the requirements:
#
#   A.) PRELIM GRADE = 50% Prelim Exam + 50% Prelim Class Standing (CS)
#   B.) PRELIM CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
#   C.) MIDTERM GRADE = 1/3 of PRELIM GRADE + 2/3 of (50% Midterm Exam + 50% Midterm Class Standing (CS))
#   D.) MIDTERM CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
#   E.) FINAL GRADE = 1/3 of MIDTERM GRADE + 2/3 of (50% Final Exam + 50% Final Class Standing (CS))
#   F.) FINAL CS = 50% Hands-on activity + 30% Quiz + 20% Assignment
#
#     HOAs, Quizzes and Assignments are inputted as average of all submissions and are out of 100%.
#     Major exams are inputted out of 100%.
#     Show the codes that successfully run the program.
#     Provide comments or documentation strings for your program.

# %% [markdown]
# **Supplementary Activity**:
# 1. **Test 3 students from the program you created.**
# 2. **The program should show the name of the student, the PRELIM, MIDTERM and FINAL grades.**
# 3. **Convert the final grade into the T.I.P.s numerical grade. Please refer to the grading system.**

# %%
# Place all the output of the procedures here
# Carl Andrei D. Torres CPE12S2 CPE009A

#--Enter the name of Student 1--
print("Enter your Name:")
x = str(input())

#--Calculates the Prelim Grade of Student 1--
PHOA = float(input("Enter Prelim Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))
PCS = PHOA * 0.5 + PQUIZ * 0.3 + PAS * 0.2
print("Prelim CS is:", "%.2f" % PCS)

PEX = float(input("Enter Prelim Exam grade: "))
PG = PEX * 0.5 + PCS * 0.5
print("Prelim Grade is:", "%.2f" % PG)

#--Calculates the Midterm Grade of Student 1--
MHOA = float(input("Enter Midterm Hands-on Activity grade: "))
MQUIZ = float(input("Enter Midterm Quiz grade: "))
MAS = float(input("Enter Midterm Assignment grade: "))
MCS = MHOA * 0.5 + MQUIZ * 0.3 + MAS * 0.2
print("Midterm CS is:", "%.2f" % MCS)

MEX = float(input("Enter Midterm Exam grade: "))
MGradePart = MEX * 0.5 + MCS * 0.5
MG = (PG * (1/3)) + (MGradePart * (2/3))
print("Midterm Grade is:", "%.2f" % MG)

#--Calculates the Final Grade of Student 1--
FHOA = float(input("Enter Final Hands-on Activity grade: "))
FQUIZ = float(input("Enter Final Quiz grade: "))
FAS = float(input("Enter Final Assignment grade: "))
FCS = FHOA * 0.5 + FQUIZ * 0.3 + FAS * 0.2
print("Finals CS is:", "%.2f" % FCS)

FEX = float(input("Enter Final Exam grade: "))
FGradePart = FEX * 0.5 + FCS * 0.5
FG = (MG * (1/3)) + (FGradePart * (2/3))
print("Finals Grade is:", "%.2f" % FG)

def equivalent(grade):
    if 99 <= grade <= 100:
        return 1.00
    elif 96 <= grade <= 98:
        return 1.25
    elif 93 <= grade <= 95:
        return 1.50
    elif 90 <= grade <= 92:
        return 1.75
    elif 87 <= grade <= 89:
        return 2.00
    elif 84 <= grade <= 86:
        return 2.25
    elif 81 <= grade <= 83:
        return 2.50
    elif 78 <= grade <= 80:
        return 2.75
    elif 75 <= grade <= 77:
        return 3.00
    elif grade < 75:
        return 5.00

#--Final Equivalent Grade Result
equiv = get_equivalent(FG)
print("Equivalent Grade:", equiv)
# Out:
# Enter your Name:
# Carl
# Enter Prelim Hands-on Activity grade: 95
# Enter Prelim Quiz grade: 97
# Enter Prelim Assignment grade: 95
# Prelim CS is: 95.60
# Enter Prelim Exam grade: 94
# Prelim Grade is: 94.80
# Enter Midterm Hands-on Activity grade: 89
# Enter Midterm Quiz grade: 96
# Enter Midterm Assignment grade: 95
# Midterm CS is: 92.30
# Enter Midterm Exam grade: 98
# Midterm Grade is: 95.03
# Enter Final Hands-on Activity grade: 96
# Enter Final Quiz grade: 97
# Enter Final Assignment grade: 89
# Finals CS is: 94.90
# Enter Final Exam grade: 95
# Finals Grade is: 94.98
# Equivalent Grade: (1.5,)

# %%
# Place all the output of the procedures here
# Carl Andrei D. Torres CPE12S2 CPE009A

#--Enter the name of Student 1--
print("Enter your Name:")
x = str(input())

#--Calculates the Prelim Grade of Student 1--
PHOA = float(input("Enter Prelim Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))
PCS = PHOA * 0.5 + PQUIZ * 0.3 + PAS * 0.2
print("Prelim CS is:", "%.2f" % PCS)

PEX = float(input("Enter Prelim Exam grade: "))
PG = PEX * 0.5 + PCS * 0.5
print("Prelim Grade is:", "%.2f" % PG)

#--Calculates the Midterm Grade of Student 1--
MHOA = float(input("Enter Midterm Hands-on Activity grade: "))
MQUIZ = float(input("Enter Midterm Quiz grade: "))
MAS = float(input("Enter Midterm Assignment grade: "))
MCS = MHOA * 0.5 + MQUIZ * 0.3 + MAS * 0.2
print("Midterm CS is:", "%.2f" % MCS)

MEX = float(input("Enter Midterm Exam grade: "))
MGradePart = MEX * 0.5 + MCS * 0.5
MG = (PG * (1/3)) + (MGradePart * (2/3))
print("Midterm Grade is:", "%.2f" % MG)

#--Calculates the Final Grade of Student 1--
FHOA = float(input("Enter Final Hands-on Activity grade: "))
FQUIZ = float(input("Enter Final Quiz grade: "))
FAS = float(input("Enter Final Assignment grade: "))
FCS = FHOA * 0.5 + FQUIZ * 0.3 + FAS * 0.2
print("Finals CS is:", "%.2f" % FCS)

FEX = float(input("Enter Final Exam grade: "))
FGradePart = FEX * 0.5 + FCS * 0.5
FG = (MG * (1/3)) + (FGradePart * (2/3))
print("Finals Grade is:", "%.2f" % FG)

def equivalent(grade):
    if 99 <= grade <= 100:
        return 1.00
    elif 96 <= grade <= 98:
        return 1.25
    elif 93 <= grade <= 95:
        return 1.50
    elif 90 <= grade <= 92:
        return 1.75
    elif 87 <= grade <= 89:
        return 2.00
    elif 84 <= grade <= 86:
        return 2.25
    elif 81 <= grade <= 83:
        return 2.50
    elif 78 <= grade <= 80:
        return 2.75
    elif 75 <= grade <= 77:
        return 3.00
    elif grade < 75:
        return 5.00

#--Final Equivalent Grade Result
equiv = get_equivalent(FG)
print("Equivalent Grade:", equiv)
# Out:
# Enter your Name:
# Enri
# Enter Prelim Hands-on Activity grade: 89
# Enter Prelim Quiz grade: 96
# Enter Prelim Assignment grade: 80
# Prelim CS is: 89.30
# Enter Prelim Exam grade: 83
# Prelim Grade is: 86.15
# Enter Midterm Hands-on Activity grade: 85
# Enter Midterm Quiz grade: 89
# Enter Midterm Assignment grade: 93
# Midterm CS is: 87.80
# Enter Midterm Exam grade: 95
# Midterm Grade is: 89.65
# Enter Final Hands-on Activity grade: 93
# Enter Final Quiz grade: 90
# Enter Final Assignment grade: 89
# Finals CS is: 91.30
# Enter Final Exam grade: 95
# Finals Grade is: 91.98
# Equivalent Grade: (1.75,)

# %%
# Place all the output of the procedures here
# Carl Andrei D. Torres CPE12S2 CPE009A

#--Enter the name of Student 1--
print("Enter your Name:")
x = str(input())

#--Calculates the Prelim Grade of Student 1--
PHOA = float(input("Enter Prelim Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))
PCS = PHOA * 0.5 + PQUIZ * 0.3 + PAS * 0.2
print("Prelim CS is:", "%.2f" % PCS)

PEX = float(input("Enter Prelim Exam grade: "))
PG = PEX * 0.5 + PCS * 0.5
print("Prelim Grade is:", "%.2f" % PG)

#--Calculates the Midterm Grade of Student 1--
MHOA = float(input("Enter Midterm Hands-on Activity grade: "))
MQUIZ = float(input("Enter Midterm Quiz grade: "))
MAS = float(input("Enter Midterm Assignment grade: "))
MCS = MHOA * 0.5 + MQUIZ * 0.3 + MAS * 0.2
print("Midterm CS is:", "%.2f" % MCS)

MEX = float(input("Enter Midterm Exam grade: "))
MGradePart = MEX * 0.5 + MCS * 0.5
MG = (PG * (1/3)) + (MGradePart * (2/3))
print("Midterm Grade is:", "%.2f" % MG)

#--Calculates the Final Grade of Student 1--
FHOA = float(input("Enter Final Hands-on Activity grade: "))
FQUIZ = float(input("Enter Final Quiz grade: "))
FAS = float(input("Enter Final Assignment grade: "))
FCS = FHOA * 0.5 + FQUIZ * 0.3 + FAS * 0.2
print("Finals CS is:", "%.2f" % FCS)

FEX = float(input("Enter Final Exam grade: "))
FGradePart = FEX * 0.5 + FCS * 0.5
FG = (MG * (1/3)) + (FGradePart * (2/3))
print("Finals Grade is:", "%.2f" % FG)

def equivalent(grade):
    if 99 <= grade <= 100:
        return 1.00
    elif 96 <= grade <= 98:
        return 1.25
    elif 93 <= grade <= 95:
        return 1.50
    elif 90 <= grade <= 92:
        return 1.75
    elif 87 <= grade <= 89:
        return 2.00
    elif 84 <= grade <= 86:
        return 2.25
    elif 81 <= grade <= 83:
        return 2.50
    elif 78 <= grade <= 80:
        return 2.75
    elif 75 <= grade <= 77:
        return 3.00
    elif grade < 75:
        return 5.00

#--Final Equivalent Grade Result
equiv = get_equivalent(FG)
print("Equivalent Grade:", equiv)
# Out:
# Enter your Name:
# Trae
# Enter Prelim Hands-on Activity grade: 95
# Enter Prelim Quiz grade: 86
# Enter Prelim Assignment grade: 87
# Prelim CS is: 90.70
# Enter Prelim Exam grade: 94
# Prelim Grade is: 92.35
# Enter Midterm Hands-on Activity grade: 95
# Enter Midterm Quiz grade: 96
# Enter Midterm Assignment grade: 93
# Midterm CS is: 94.90
# Enter Midterm Exam grade: 95
# Midterm Grade is: 94.08
# Enter Final Hands-on Activity grade: 96
# Enter Final Quiz grade: 98
# Enter Final Assignment grade: 96
# Finals CS is: 96.60
# Enter Final Exam grade: 93
# Finals Grade is: 94.56
# Equivalent Grade: (1.5,)

# %% [markdown]
# **Questions**: (write your answers in blue font color and questions in black)
#
# 1.   List item
# 2.   List item

# %% [markdown]
# **Conclusion**:
# (conclusion must be based from the objective and answers whether you attained the objective/s or not and a brief explanation how you attained it)

# %%
PHOA = float(input("Enter Hands-on Activity grade: "))
PQUIZ = float(input("Enter Prelim Quiz grade: "))
PAS = float(input("Enter Prelim Assignment grade: "))
PCS = PHOA*.5 + PQUIZ*.3 + PAS*.2
print("Prelim CS is: ", PCS)
PEX = float(input("Enter Prelim Exam grade: "))
PG = PEX*.5 + PCS*.5
print("Prelim Grade is: ", "%.2f" % PG)
# Out:
# Enter Hands-on Activity grade: 100
# Enter Prelim Quiz grade: 85
# Enter Prelim Assignment grade: 50
# Prelim CS is:  85.5
# Enter Prelim Exam grade: 75
# Prelim Grade is:  80.25
